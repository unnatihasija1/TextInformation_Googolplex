# %% [markdown]
# ### **Implementation Details**
#
#
# #### **Step 3: Exploratory Analysis and Baseline Sentiment Analysis Using VADER**
# abc abc to be updated

# %%
# Libraries

import nltk
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import re
import string

# Download the lexicon
nltk.download("vader_lexicon")
from nltk.probability import FreqDist

from wordcloud import WordCloud

# Import the lexicon 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Create an instance of SentimentIntensityAnalyzer
sent_analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\I068230\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_pickle('../source/nlp_cleaned_df.pkl')
df.head()
# Out:
#    Unnamed: 0                       Date                   ID  \
# 0           0  2022-11-07 23:59:59+00:00  1589769667765469186
# 1           1  2022-11-07 23:59:59+00:00  1589769667652235267
# 2           2  2022-11-07 23:59:59+00:00  1589769667127934977
# 3           3  2022-11-07 23:59:59+00:00  1589769666918244352
# 4           4  2022-11-07 23:59:59+00:00  1589769666679144448
#
#                   location                                              tweet  \
# 0          California, USA  Taking into account personal contributions &am...
# 1  @jlo follows ♡ 01.29.21  whats your fav song?\n\n❥ I’m voting #Jennifer...
# 2                  Unknown  @MayoIsSpicyy He is allowed to speak his opini...
# 3                     USA   HEY NY DISTRICT 10! PLEASE VOTE FOR @danielsgo...
# 4                      DMV  @YDanasmithdutra @BaddCompani @politicalblond ...
#
#    num_of_likes  num_of_retweet language  \
# 0             2               1       en
# 1             0              10       en
# 2             0               0       en
# 3             1               1       en
# 4             3               0       en
#
#                                       cleaned_tweets  \
# 0  taking account personal bad everyone better tr...
# 1                                  whats song voting
# 2  speak opinion like rest us opinion vote republ...
# 3                           hey district please vote
# 4                                   vote blue matter
#
#                                 final_cleaned_tweets
# 0  taking account personal bad everyone better tr...
# 1                                  whats song voting
# 2  speak opinion like rest u opinion vote republi...
# 3                           hey district please vote
# 4                                   vote blue matter

# %%
# Calculate Tokens
def unfiltered_tokens(text):
    wordtokens = nltk.word_tokenize(text)
    return wordtokens

data_tweets = df['cleaned_tweets']
unfilterd_data = list(map(unfiltered_tokens, data_tweets))
flat_unfiltered = [item for sublist in unfilterd_data for item in sublist]
# getting frequency distribution
corpus_freqdist = FreqDist(flat_unfiltered)
corpus_freqdist.most_common(20)
# Out:
# [('vote', 9827),
#  ('voting', 4086),
#  ('election', 3992),
#  ('democrats', 2675),
#  ('republican', 1980),
#  ('people', 1836),
#  ('tomorrow', 1538),
#  ('year', 1280),
#  ('like', 1124),
#  ('day', 1114),
#  ('get', 1100),
#  ('pay', 1012),
#  ('favorite', 972),
#  ('red', 930),
#  ('blue', 863),
#  ('dont', 835),
#  ('us', 831),
#  ('one', 828),
#  ('want', 803),
#  ('would', 793)]

# %%
data_nlptweets = df['final_cleaned_tweets']
processed_data = list(map(unfiltered_tokens, data_nlptweets))
flat_processed = [item for sublist in processed_data for item in sublist]
# getting frequency distribution
corpus_freqdist2 = FreqDist(flat_processed)
corpus_freqdist2.most_common(20)
# Out:
# [('vote', 9827),
#  ('voting', 4086),
#  ('election', 3992),
#  ('democrat', 3238),
#  ('republican', 1980),
#  ('people', 1836),
#  ('tomorrow', 1538),
#  ('day', 1299),
#  ('year', 1280),
#  ('like', 1124),
#  ('get', 1100),
#  ('pay', 1012),
#  ('u', 981),
#  ('favorite', 972),
#  ('red', 930),
#  ('blue', 868),
#  ('dont', 835),
#  ('one', 828),
#  ('want', 803),
#  ('would', 793)]

# %%
# create counts of hate and not hate with values and words
clean_bar_counts = [x[1] for x in corpus_freqdist.most_common(20)]
clean_bar_words = [x[0] for x in corpus_freqdist.most_common(20)]

cleanNLP_bar_counts = [x[1] for x in corpus_freqdist2.most_common(20)]
cleanNLP_bar_words = [x[0] for x in corpus_freqdist2.most_common(20)]

# set the color of the bar graphs
color = cm.BuGn(np.linspace(.4,.8, 30))

# %%
new_figure = plt.figure(figsize=(14,6))

ax = new_figure.add_subplot(121)
ax.invert_yaxis()

ax2 = new_figure.add_subplot(122)
ax2.invert_yaxis()

# generating a bar chart on each axes
ax.barh(clean_bar_words, clean_bar_counts, color=color)
ax2.barh(cleanNLP_bar_words, cleanNLP_bar_counts, color=color)

ax.title.set_text('Pre Stopwords and Lemmatization')
ax2.title.set_text('Post Stopwords and Lemmatization')

for ax in new_figure.axes:
    plt.sca(ax)
    plt.xticks(rotation=60, fontsize=14)
    plt.xlabel("Word Count")
    plt.yticks(fontsize=14)
plt.tight_layout(pad=2)

new_figure.suptitle('Top 20 Most Frequent Words per Label', fontsize=16)

plt.savefig('../visualization/label_word_count_y.png', bbox_inches = "tight", pad_inches=.5)
plt.show()

# %%
tweet_string = ','.join(list(df['final_cleaned_tweets'].values))  ## Joining processed tweets to form a string
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')  # Wordcloud Object
word_object = wordcloud.generate(tweet_string)  ## Generating wordcloud

plt.figure(figsize=(6,6), facecolor='k')
plt.imshow(word_object, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
plt.savefig('../visualization/wordcloud.png')

# %% [markdown]
# * Sentiment Analysis using Vader

# %%
# Helper function
# format VADER's output based on compound

def format_polarity(vader_obj):
  polarity = "neutral"
  if(vader_obj['compound']>= 0.05):
    polarity = "positive"
  elif(vader_obj['compound']<= -0.05):
    polarity = "negative"
  return polarity

# get polarity
def predict_sentiment(text):
  vader_obj =  sent_analyzer.polarity_scores(text)
  return format_polarity(vader_obj)

#get vader predictions 
def get_vader_obj(text):
  vader_obj =  sent_analyzer.polarity_scores(text)
  return vader_obj

# %%
# Run the predictions on tweet, cleaned and nlp final columns
df["sentiment_Original"] = df["tweet"].apply(predict_sentiment)
df["sentiment_cleaned"] = df["cleaned_tweets"].apply(predict_sentiment)
df["sentiment_nlpfinal"] = df["final_cleaned_tweets"].apply(predict_sentiment)

# Vader Polarity object for final tweets
df["vader_polarity"] = df["final_cleaned_tweets"].apply(get_vader_obj)
df.head()

df.to_pickle('../source/nlp_sentiments.pkl')

# %%
# Visualization change in Sentiment with Text processing

sentiments_orig = df['sentiment_Original'].value_counts()
sentiments_orig
# Out:
# positive    8147
# negative    5448
# neutral     5091
# Name: sentiment_Original, dtype: int64

# %%
# Visualization change in Sentiment with Text processing

sentiments_cleanedtweets = df['sentiment_cleaned'].value_counts()
sentiments_cleanedtweets
# Out:
# positive    7456
# neutral     6467
# negative    4763
# Name: sentiment_cleaned, dtype: int64

# %%
# Visualization change in Sentiment with Text processing

sentiments_nlpcleaned = df['sentiment_nlpfinal'].value_counts()
sentiments_nlpcleaned
# Out:
# positive    7475
# neutral     6484
# negative    4727
# Name: sentiment_nlpfinal, dtype: int64

# %%
sentplot = [[sentiments_orig[0], sentiments_cleanedtweets[0],sentiments_nlpcleaned[0]],
              [sentiments_orig[1], sentiments_cleanedtweets[1],sentiments_nlpcleaned[1]],
              [sentiments_orig[2], sentiments_cleanedtweets[2],sentiments_nlpcleaned[2]]]
print(sentplot)          

#sentlabel = ['Positive', 'Negative', 'Neutral']
positive = [sentiments_orig[0], sentiments_cleanedtweets[0],sentiments_nlpcleaned[0]]#sentplot[0]
negative = [sentiments_orig[1], sentiments_cleanedtweets[1],sentiments_nlpcleaned[1]] #sentplot[1]
neutral = [sentiments_orig[2], sentiments_cleanedtweets[2],sentiments_nlpcleaned[2]] #sentplot[2]

x = np.arange(3)  
width = 0.20  # the width of the bars

#fig, ax = plt.subplots()
rects1 = plt.bar(x + 0.00, positive, width, label= 'Positive')
rects2 = plt.bar(x + 0.25, negative, width, label= 'Negative')
rects3 = plt.bar(x + 0.50, neutral, width, label= 'Neutral')

plt.ylabel('Count of sentiments')
plt.title('Sentiments before and after cleaning')
plt.xticks(x, ['Original', 'Cleaned', 'NLPCleaned'])
plt.legend(loc='lower right')


plt.show()
plt.savefig('../visualization/sentimentcomparison.png')
# Out:
# [[8147, 7456, 7475], [5448, 6467, 6484], [5091, 4763, 4727]]

# %% [markdown]
# * Parsing Polarity Scores

# %%
df.head()
# Out:
#    Unnamed: 0                       Date                   ID  \
# 0           0  2022-11-07 23:59:59+00:00  1589769667765469186
# 1           1  2022-11-07 23:59:59+00:00  1589769667652235267
# 2           2  2022-11-07 23:59:59+00:00  1589769667127934977
# 3           3  2022-11-07 23:59:59+00:00  1589769666918244352
# 4           4  2022-11-07 23:59:59+00:00  1589769666679144448
#
#                   location                                              tweet  \
# 0          California, USA  Taking into account personal contributions &am...
# 1  @jlo follows ♡ 01.29.21  whats your fav song?\n\n❥ I’m voting #Jennifer...
# 2                  Unknown  @MayoIsSpicyy He is allowed to speak his opini...
# 3                     USA   HEY NY DISTRICT 10! PLEASE VOTE FOR @danielsgo...
# 4                      DMV  @YDanasmithdutra @BaddCompani @politicalblond ...
#
#    num_of_likes  num_of_retweet language  \
# 0             2               1       en
# 1             0              10       en
# 2             0               0       en
# 3             1               1       en
# 4             3               0       en
#
#                                       cleaned_tweets  \
# 0  taking account personal bad everyone better tr...
# 1                                  whats song voting
# 2  speak opinion like rest us opinion vote republ...
# 3                           hey district please vote
# 4                                   vote blue matter
#
#                                 final_cleaned_tweets sentiment_Original  \
# 0  taking account personal bad everyone better tr...           positive
# 1                                  whats song voting           positive
# 2  speak opinion like rest u opinion vote republi...           negative
# 3                           hey district please vote           positive
# 4                                   vote blue matter           negative
#
#   sentiment_cleaned sentiment_nlpfinal  \
# 0          positive           positive
# 1           neutral            neutral
# 2          positive           positive
# 3          positive           positive
# 4           neutral            neutral
#
#                                       vader_polarity
# 0  {'neg': 0.271, 'neu': 0.403, 'pos': 0.326, 'co...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...
# 3  {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'comp...
# 4  {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'comp...

# %%
df_polarity = df.drop(['Unnamed: 0', 'Date', 'ID', 'location', 'tweet', 'num_of_likes','num_of_retweet', 'language' , 'cleaned_tweets' ,'sentiment_Original' , 'sentiment_cleaned'], axis=1)

# %%
df_polarity_scores = df_polarity['vader_polarity'].apply(pd.Series)

# %%
df_polarity_scores.head()
# Out:
#      neg    neu    pos  compound
# 0  0.271  0.403  0.326    0.5994
# 1  0.000  1.000  0.000    0.0000
# 2  0.000  0.828  0.172    0.3612
# 3  0.000  0.566  0.434    0.3182
# 4  0.000  0.645  0.355    0.0258

# %%
df_m1 = df[['final_cleaned_tweets','sentiment_nlpfinal']].copy()

# %%
df_merge = pd.merge(left=df_m1, left_index=True , right=df_polarity_scores, right_index= True, how='inner')
#df_merge = pd.merge(left=df_polarity_scores, left_index=True , right=df_polarity_scores, right_index= True, how='inner')

# %%
df_merge.head()
# Out:
#    neg_x  neu_x  pos_x  compound_x  neg_y  neu_y  pos_y  compound_y
# 0  0.271  0.403  0.326      0.5994  0.271  0.403  0.326      0.5994
# 1  0.000  1.000  0.000      0.0000  0.000  1.000  0.000      0.0000
# 2  0.000  0.828  0.172      0.3612  0.000  0.828  0.172      0.3612
# 3  0.000  0.566  0.434      0.3182  0.000  0.566  0.434      0.3182
# 4  0.000  0.645  0.355      0.0258  0.000  0.645  0.355      0.0258

# %%
scores_df = df_merge.groupby('sentiment_nlpfinal')['pos'].mean().reset_index(name='avg_positive')
scores_df['avg_neutral'] = df_merge.groupby('sentiment_nlpfinal')['neu'].mean()
scores_df['avg_negative'] = df_merge.groupby('sentiment_nlpfinal')['neg'].mean()
scores_df['avg_compound'] = df_merge.groupby('sentiment_nlpfinal')['compound'].mean()

scores_df.head()
# Out:
#   sentiment_nlpfinal  avg_positive  avg_neutral  avg_negative  avg_compound
# 0           negative      0.070076          NaN           NaN           NaN
# 1            neutral      0.009765          NaN           NaN           NaN
# 2           positive      0.393567          NaN           NaN           NaN
